# %% [markdown]
# <a href="https://colab.research.google.com/github/nimitsajal/Count-Down-Timer/blob/master/Movie_Data_Set_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Imports**

# %%
from bs4 import BeautifulSoup as bs
from datetime import datetime as dt
import requests
import re

# %% [markdown]
# ## **TASK 1**
# *Grab all the Info from the Side Panel from the webpage and store them in a Dictionary - https://en.wikipedia.org/wiki/Toy_Story_3*

# %%
# Loading the Webpage

r = requests.get("https://en.wikipedia.org/wiki/Toy_Story_3")
webpage = bs(r.content)
# print(webpage.pret

# %%
# Grabbing the Side Info Panel and storing them in a dictionary

movie_info = {}
panel = webpage.find("table", attrs={"class": "infobox vevent"}).find_all("tbody")[0].find_all("tr")
for index, tr in enumerate(panel):
  if index == 0:
    movie_info["Title"] = tr.get_text(" ", strip=True)
  elif index == 1:
    continue
  else:
    key = tr.find("th").get_text(" ", strip=True)
    if tr.find("li"):
      value = [item.get_text(" ", strip=True).replace("\xa0", "") for item in tr.find_all("li")]
    else:
      value = tr.find("td").get_text(" ", strip=True).replace("\xa0", "")

    movie_info[key] = value
movie_info
# Out:
# {'Box office': '$1.067billion [1]',
#  'Budget': '$200million [1]',
#  'Cinematography': ['Jeremy Lasky', 'Kim White'],
#  'Country': 'United States',
#  'Directed by': 'Lee Unkrich',
#  'Distributed by': 'Walt Disney Studios Motion Pictures',
#  'Edited by': 'Ken Schretzmann',
#  'Language': 'English',
#  'Music by': 'Randy Newman',
#  'Produced by': 'Darla K. Anderson',
#  'Production companies': ['Walt Disney Pictures', 'Pixar Animation Studios'],
#  'Release date': ['June12,2010 ( 2010-06-12 ) ( Taormina Film Fest )',
#   'June18,2010 ( 2010-06-18 ) (United States)'],
#  'Running time': '103 minutes [1]',
#  'Screenplay by': 'Michael Arndt',
#  'Starring': ['Tom Hanks',
#   'Tim Allen',
#   'Joan Cusack',
#   'Don Rickles',
#   'Wallace Shawn',
#   'John Ratzenberger',
#   'Estelle Harris',
#   'Ned Beatty',
#   'Michael Keaton',
#   'Jodi Benson',
#   'John Morris'],
#  'Story by': ['John Lasseter', 'Andrew Stanton', 'Lee Unkrich'],
#  'Title': 'Toy Story 3'}

# %% [markdown]
# ## **TASK 2**
# *Grab all the Info from the Side Panel from all the Movies from the main Disney Movies webpage and store them in a Dictionary - https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films*

# %%
# Loading the Webpage

r = requests.get("https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films")
webpage = bs(r.content)
# print(webpage.prettify())

# %%
# Grabbing the links to individual movie pages

baseLink = "https://en.wikipedia.org/"
movie_infos = []

links = webpage.select("table.wikitable.sortable tbody tr td i a")

for index, link in enumerate(links):
  try:
    actualLink = baseLink + link["href"]

    # Loading the Webpage
    r = requests.get(actualLink)
    moviePage = bs(r.content)
    
    # Grabbing the Side Info Panel and storing them in a dictionary
    movie_info = {}
    panel = moviePage.find("table", attrs={"class": "infobox vevent"})
    # print(panel)
    panel = panel.find("tbody")
    panel = panel.select("tr")
    for index, tr in enumerate(panel):
      if index == 0:
        movie_info["Title"] = tr.get_text(" ", strip=True)
      elif index == 1:
        continue
      else:
        key = tr.find("th").get_text(" ", strip=True)
        if tr.find("li"):
          value = [item.get_text(" ", strip=True).replace("\xa0", "") for item in tr.find_all("li")]
        else:
          value = tr.find("td").get_text(" ", strip=True).replace("\xa0", "")

        movie_info[key] = value
        
  except Exception as e:
    E = e
  
  movie_infos.append(movie_info)
for movies in movie_infos:
  print(movies.get("Release date"))
# Out:
# ['May19,1937 ( 1937-05-19 )']
# ['December21,1937 ( 1937-12-21 ) ( Carthay Circle Theatre )']
# ['February7,1940 ( 1940-02-07 ) ( Center Theatre ) [1]', 'February23,1940 ( 1940-02-23 ) (United States) [2]']
# ['November13,1940 ( 1940-11-13 )']
# ['June27,1941 ( 1941-06-27 ) [1]']
# ['October23,1941 ( 1941-10-23 ) (New York City) [1]', 'October31,1941 ( 1941-10-31 ) (U.S.)']
# ['August9,1942 ( 1942-08-09 ) (World Premiere – London)', 'August13,1942 ( 1942-08-13 ) (Premiere – New York City)', 'August21,1942 ( 1942-08-21 ) (U.S.) [1]']
# ['August24,1942 ( 1942-08-24 ) (World Premiere – Rio de Janeiro)', 'February6,1943 ( 1943-02-06 ) (U.S. Premiere – Boston)', 'February19,1943 ( 1943-02-19 ) (U.S.) [1]']
# ['July17,1943 ( 1943-07-17 )']
# ['December21,1944 ( 1944-12-21 ) (Mexico City)', 'February3,1945 ( 1945-02-03 ) (US) [1]']
# ['April20,1946 ( 1946-04-20 ) (New York City premiere) [1]', 'August15,1946 ( 1946-08-15 ) (U.S.) [1]']
# ['November12,1946 ( 1946-11-12 ) (Premiere: Atlanta, Georgia) [1]', 'November20,1946 ( 1946-11-20 ) [1]', 'March30,1947 ( 1947-03-30 ) (Stanford Theatre, Palo Alto, California) [2]']
# ['September27,1947 ( 1947-09-27 )']
# May27,1948 ( 1948-05-27 )
# November 29, 1948 (Chicago, Illinois) January 19, 1949 (Indianapolis, Indiana) [1]
# ['October5,1949 ( 1949-10-05 )']
# ['February15,1950 ( 1950-02-15 ) (Boston)', 'March4,1950 ( 1950-03-04 ) (United States)']
# ['June22,1950 ( 1950-06-22 ) (World Premiere-London) [1]', 'July29,1950 ( 1950-07-29 ) (US) [1]']
# ['July26,1951 ( 1951-07-26 ) (London, premiere) [1]', 'July28,1951 ( 1951-07-28 ) (New York City, premiere) [1]']
# ['March13,1952 ( 1952-03-13 ) (Premiere- London ) [2]', 'June26,1952 ( 1952-06-26 ) ( US ) [2]']
# ['February5,1953 ( 1953-02-05 ) (United States) [1]']
# ["July23,1953 ( 1953-07-23 ) ('US ) [1]"]
# ['November10,1953 ( 1953-11-10 )']
# ['26October1953 ( 1953-10-26 ) (Premiere- London ) [1]', '27February1954 ( 1954-02-27 ) ( US ) [1]']
# ['August17,1954 ( 1954-08-17 )']
# ['December23,1954 ( 1954-12-23 )']
# May25,1955 ( 1955-05-25 )
# ['June22,1955 ( 1955-06-22 )']
# ['September14,1955 ( 1955-09-14 ) [1]']
# December22,1955 ( 1955-12-22 )
# June 8, 1956 [1]
# July18,1956 ( 1956-07-18 )
# ['September4,1956 ( 1956-09-04 )']
# ['December20,1956 ( 1956-12-20 )']
# June19,1957 ( 1957-06-19 )
# August28,1957 ( 1957-08-28 )
# ['December25,1957 ( 1957-12-25 )']
# ['July8,1958 ( 1958-07-08 )']
# ['August12,1958 ( 1958-08-12 )']
# ['December25,1958 ( 1958-12-25 )']
# ['January29,1959 ( 1959-01-29 )']
# ['March19,1959 ( 1959-03-19 )']
# ['June24,1959 ( 1959-06-24 ) (Dublin) [1]', 'June26,1959 ( 1959-06-26 ) (Los Angeles) [1]']
# None
# ['November10,1959 ( 1959-11-10 )']
# January 21, 1960 ( Sarasota, FL ) [2]
# ['February24,1960 ( 1960-02-24 )']
# May19,1960 ( 1960-05-19 )
# None
# ['June1960 ( 1960-06 ) ( Berlin )', 'August10,1960 ( 1960-08-10 ) (US)']
# ['November1,1960 ( 1960-11-01 )']
# ['December21,1960 ( 1960-12-21 )']
# ['January25,1961 ( 1961-01-25 )']
# March 16, 1961 [1]
# ['June21,1961 ( 1961-06-21 )']
# ['July12,1961 ( 1961-07-12 )']
# ['July17,1961 ( 1961-07-17 )']
# ['December14,1961 ( 1961-12-14 )']
# April5,1962 ( 1962-04-05 )
# ['May17,1962 ( 1962-05-17 )']
# ['June6,1962 ( 1962-06-06 )']
# September 26, 1962
# ['November7,1962 ( 1962-11-07 ) (Los Angeles) [1]']
# ['November14,1962 ( 1962-11-14 ) (London, premiere)', 'December19,1962 ( 1962-12-19 ) (US)']
# ['January16,1963 ( 1963-01-16 )']
# ['March29,1963 ( 1963-03-29 ) (U.S.)']
# ['June1,1963 ( 1963-06-01 )']
# ['July7,1963 ( 1963-07-07 )']
# November20,1963 ( 1963-11-20 )
# ['December25,1963 ( 1963-12-25 )']
# ['March12,1964 ( 1964-03-12 )']
# ['February11,1964 ( 1964-02-11 ) (Los Angeles) [1]']
# ['11December1963 ( 1963-12-11 ) ( New York City )', '4June1964 ( 1964-06-04 ) (U.S.)']
# ['July2,1964 ( 1964-07-02 )']
# ['August27,1964 ( 1964-08-27 ) (LA)', 'September24,1964 ( 1964-09-24 ) (NY)']
# November 10, 1964 [1]
# ['December18,1964 ( 1964-12-18 )']
# ['August18,1965 ( 1965-08-18 ) (Los Angeles) [1]']
# ['December2,1965 ( 1965-12-02 )']
# ['February4,1966 ( 1966-02-04 ) (premiere)', 'February16,1966 ( 1966-02-16 )']
# ['June25,1966 ( 1966-06-25 ) (San Diego) [1]', 'June29,1966 ( 1966-06-29 ) (U.S.) [1]']
# October 1, 1966
# ['December1,1966 ( 1966-12-01 )']
# ['February8,1967 ( 1967-02-08 ) (San Francisco) [1]']
# ['June15,1967 ( 1967-06-15 ) (uk)']
# ['July12,1967 ( 1967-07-12 ) [1]']
# ['October18,1967 ( 1967-10-18 )']
# ['October19,1967 ( 1967-10-19 )']
# ['June23,1967 ( 1967-06-23 )', 'November30,1967 ( 1967-11-30 )']
# ['February8,1968 ( 1968-02-08 )']
# ['March21,1968 ( 1968-03-21 ) ( Radio City Music Hall )']
# ['June26,1968 ( 1968-06-26 )']
# ['December3,1968 ( 1968-12-03 )']
# ['December24,1968 ( 1968-12-24 ) (limited)', 'March13,1969 ( 1969-03-13 ) (wide)']
# ['May9,1969 ( 1969-05-09 )']
# September4,1969 ( 1969-09-04 )
# ['November28,1969 ( 1969-11-28 )']
# ['February11,1970 ( 1970-02-11 )']
# July1,1970 ( 1970-07-01 )
# ['December15,1970 ( 1970-12-15 ) (original release)', 'January20,1971 ( 1971-01-20 )']
# ['December11,1970 ( 1970-12-11 ) (premiere)', 'December24,1970 ( 1970-12-24 ) (United States)']
# March 17, 1971 ( 1971 )
# June 22, 1971
# ['June30,1971 ( 1971-06-30 )']
# ['October7,1971 ( 1971-10-07 ) (United Kingdom)', 'December13,1971 ( 1971-12-13 ) (United States)']
# ['March22,1972 ( 1972-03-22 ) (US)']
# July12,1972 ( 1972-07-12 )
# ['July5,1972 ( 1972-07-05 )']
# ['October18,1972 ( 1972-10-18 )']
# ['December22,1972 ( 1972-12-22 )']
# February 1, 1973 [1]
# ['March23,1973 ( 1973-03-23 )']
# None
# ['November8,1973 ( 1973-11-08 )']
# ['December14,1973 ( 1973-12-14 )']
# ['June6,1974 ( 1974-06-06 )']
# ['July31,1974 ( 1974-07-31 )']
# ['August1,1974 ( 1974-08-01 )']
# December 20, 1974 (with Winnie the Pooh and Tigger Too )
# ['February6,1975 ( 1975-02-06 )']
# ['March21,1975 ( 1975-03-21 ) (U.S.)']
# ['July1,1975 ( 1975-07-01 ) [1]']
# ['July9,1975 ( 1975-07-09 )']
# ['October8,1975 ( 1975-10-08 )']
# None
# December 25, 1975 [1]
# ['February11,1976 ( 1976-02-11 ) (Los Angeles) [1]']
# ['July1,1976 ( 1976-07-01 )']
# ['July7,1976 ( 1976-07-07 )']
# ['December16,1976 ( 1976-12-16 )']
# ['December17,1976 ( 1976-12-17 )']
# May 26, 1976 (UK) March 11, 1977 (US)
# ['March11,1977 ( 1977-03-11 )']
# ['June20,1977 ( 1977-06-20 )']
# ['June22,1977 ( 1977-06-22 )']
# ['June24,1977 ( 1977-06-24 )']
# ['November3,1977 ( 1977-11-03 )']
# December16,1977 ( 1977-12-16 )
# ['March10,1978 ( 1978-03-10 )']
# ['June30,1978 ( 1978-06-30 ) (New York) [1]']
# July5,1978 ( 1978-07-05 )
# February9,1979 ( 1979-02-09 )
# ['June27,1979 ( 1979-06-27 )']
# July 19, 1979 (London) [1] August 3, 1979 (Los Angeles) [1]
# ['December18,1979 ( 1979-12-18 ) (United Kingdom)', 'December21,1979 ( 1979-12-21 ) (United States)']
# None
# ['February8,1980 ( 1980-02-08 )']
# ['April17,1980 ( 1980-04-17 ) (New York City)', 'October9,1981 ( 1981-10-09 ) (U.S.)']
# ['June27,1980 ( 1980-06-27 )']
# ['July9,1980 ( 1980-07-09 ) (Los Angeles) [2]']
# ['December6,1980 ( 1980-12-06 ) ( Los Angeles )', 'December12,1980 ( 1980-12-12 ) ( United States )']
# February 11, 1981 (Los Angeles) [1]
# March20,1981 ( 1981-03-20 )
# ['June26,1981 ( 1981-06-26 )']
# ['July10,1981 ( 1981-07-10 )']
# ['August7,1981 ( 1981-08-07 )']
# February5,1982 ( 1982-02-05 )
# ['July9,1982 ( 1982-07-09 )']
# July30,1982 ( 1982-07-30 )
# ['March11,1983 ( 1983-03-11 )']
# ['April29,1983 ( 1983-04-29 ) (United States)']
# October 7, 1983 (limited) January 27, 1984 (release)
# ['June21,1985 ( 1985-06-21 ) (United States)']
# ['July24,1985 ( 1985-07-24 ) [3]']
# ['September27,1985 ( 1985-09-27 )']
# ['November22,1985 ( 1985-11-22 )']
# ['July2,1986 ( 1986-07-02 )']
# ['August1,1986 ( 1986-08-01 )']
# ['June5,1987 ( 1987-06-05 )']
# ['24March1988 ( 1988-03-24 ) (Australia)']
# ['November18,1988 ( 1988-11-18 )']
# ['June23,1989 ( 1989-06-23 )']
# August18,1989 ( 1989-08-18 )
# ['November17,1989 ( 1989-11-17 )']
# ['August3,1990 ( 1990-08-03 )']
# ['November16,1990 ( 1990-11-16 )']
# ['January18,1991 ( 1991-01-18 )']
# ['3October1990 ( 1990-10-03 )']
# ['May24,1991 ( 1991-05-24 )']
# ['June21,1991 ( 1991-06-21 )']
# ['September29,1991 ( 1991-09-29 ) ( NYFF )', 'November22,1991 ( 1991-11-22 ) (United States)']
# ['April10,1992 ( 1992-04-10 )']
# ['July17,1992 ( 1992-07-17 )']
# ['October2,1992 ( 1992-10-02 )']
# ['November25,1992 ( 1992-11-25 )']
# ['December11,1992 ( 1992-12-11 )']
# February3,1993 ( 1993-02-03 )
# ['March12,1993 ( 1993-03-12 )']
# ['April2,1993 ( 1993-04-02 )']
# ['July16,1993 ( 1993-07-16 )']
# ['October1,1993 ( 1993-10-01 )']
# ['November12,1993 ( 1993-11-12 )']
# ['January14,1994 ( 1994-01-14 )']
# ['February11,1994 ( 1994-02-11 )']
# ['April17,1994 ( 1994-04-17 )']
# ['April14,1994 ( 1994-04-14 )']
# ['June15,1994 ( 1994-06-15 ) (United States)']
# ['July15,1994 ( 1994-07-15 )']
# ['October28,1994 ( 1994-10-28 )']
# ['November11,1994 ( 1994-11-11 )']
# ['December25,1994 ( 1994-12-25 )']
# ['February17,1995 ( 1995-02-17 )']
# ['March3,1995 ( 1995-03-03 )']
# ['March24,1995 ( 1995-03-24 )']
# ['April7,1995 ( 1995-04-07 ) [1]']
# ['June10,1995 ( 1995-06-10 ) [1]', 'June23,1995 ( 1995-06-23 )']
# ['July28,1995 ( 1995-07-28 )']
# ['August11,1995 ( 1995-08-11 )']
# ['September28,1995 ( 1995-09-28 )']
# ['January22,1995 ( 1995-01-22 ) ( Sundance Film Festival )', 'October20,1995 ( 1995-10-20 ) (U.S.)']
# ['November19,1995 ( 1995-11-19 ) ( El Capitan Theatre )', 'November22,1995 ( 1995-11-22 ) (United States)']
# ['December22,1995 ( 1995-12-22 )']
# ['February16,1996 ( 1996-02-16 )']
# ['March8,1996 ( 1996-03-08 )']
# ['April12,1996 ( 1996-04-12 ) (United States)', 'August2,1996 ( 1996-08-02 ) (United Kingdom)']
# ['June21,1996 ( 1996-06-21 )']
# ['August30,1996 ( 1996-08-30 )']
# ['October4,1996 ( 1996-10-04 )']
# ['November27,1996 ( 1996-11-27 ) (United States)']
# ['February14,1997 ( 1997-02-14 )']
# ['March7,1997 ( 1997-03-07 ) (US)', 'August5,1997 ( 1997-08-05 ) (France)']
# March18,1997 ( 1997-03-18 )
# ['June13,1997 ( 1997-06-13 ) (limited release)', 'June27,1997 ( 1997-06-27 ) (wide release)']
# ['July16,1997 ( 1997-07-16 )']
# ['August1,1997 ( 1997-08-01 )']
# ['October10,1997 ( 1997-10-10 )']
# ['November16,1997 ( 1997-11-16 ) ( Pennsylvania )', 'November26,1997 ( 1997-11-26 ) (United States)']
# ['December25,1997 ( 1997-12-25 )']
# ['March27,1998 ( 1998-03-27 ) (United States)']
# ['June19,1998 ( 1998-06-19 )']
# ['July29,1998 ( 1998-07-29 ) (United States)']
# ['November13,1998 ( 1998-11-13 )']
# ['November20,1998 ( 1998-11-20 ) [1]']
# ['December25,1998 ( 1998-12-25 )']
# ['February12,1999 ( 1999-02-12 )']
# ['March26,1999 ( 1999-03-26 )']
# ['May14,1999 ( 1999-05-14 )']
# ['June12,1999 ( 1999-06-12 ) ( El Capitan Theatre )', 'June16,1999 ( 1999-06-16 ) (United States [1] )']
# ['July23,1999 ( 1999-07-23 )']
# ['May1999 ( 1999-05 ) ( Cannes )', 'October15,1999 ( 1999-10-15 ) (United States)']
# ['November13,1999 ( 1999-11-13 ) ( El Capitan Theatre ) [1]', 'November24,1999 ( 1999-11-24 ) (United States)']
# ['December17,1999 ( 1999-12-17 ) (Premiere)', 'January1,2000 ( 2000-01-01 ) ( IMAX )', 'June16,2000 ( 2000-06-16 ) (United States)']
# ['February11,2000 ( 2000-02-11 ) (United States)']
# ['March10,2000 ( 2000-03-10 )']
# ['May19,2000 ( 2000-05-19 ) (United States)']
# ['July7,2000 ( 2000-07-07 )']
# ['September29,2000 ( 2000-09-29 )']
# ['November22,2000 ( 2000-11-22 ) (United States)']
# ['December15,2000 ( 2000-12-15 )']
# ['February10,2001 ( 2001-02-10 ) (premiere)', 'February16,2001 ( 2001-02-16 ) (United States)']
# ['February27,2001 ( 2001-02-27 )']
# ['June3,2001 ( 2001-06-03 ) (premiere)', 'June15,2001 ( 2001-06-15 ) (United States)']
# ['July29,2001 ( 2001-07-29 ) ( El Capitan Theatre )', 'August3,2001 ( 2001-08-03 ) (United States)']
# ['October5,2001 ( 2001-10-05 )']
# ['October28,2001 ( 2001-10-28 ) ( El Capitan Theatre )', 'November2,2001 ( 2001-11-02 ) (United States)']
# ['January18,2002 ( 2002-01-18 )']
# ['February10,2002 ( 2002-02-10 ) ( New York City )', 'February15,2002 ( 2002-02-15 ) (United States)']
# ['February26,2002 ( 2002-02-26 )']
# ['March29,2002 ( 2002-03-29 )']
# ['June21,2002 ( 2002-06-21 )']
# ['July21,2002 ( 2002-07-21 )', 'July26,2002 ( 2002-07-26 )']
# None
# ['October11,2002 ( 2002-10-11 ) (U.S.)']
# ['November1,2002 ( 2002-11-01 )']
# ['November27,2002 ( 2002-11-27 )']
# ['January21,2003 ( 2003-01-21 )']
# ['February14,2003 ( 2003-02-14 )']
# ['March11,2003 ( 2003-03-11 )']
# ['March16,2003 ( 2003-03-16 ) (premiere)', 'March21,2003 ( 2003-03-21 ) (United States)', 'July2,2003 ( 2003-07-02 ) ( Manila , Philippines )']
# ['March31,2003 ( 2003-03-31 ) (premiere)', 'April11,2003 ( 2003-04-11 ) (limited)']
# ['April18,2003 ( 2003-04-18 ) (United States)']
# ['May2,2003 ( 2003-05-02 ) (United States)', 'August29,2003 ( 2003-08-29 ) (United Kingdom)']
# ['May30,2003 ( 2003-05-30 )']
# ['June28,2003 ( 2003-06-28 ) ( Disneyland Resort )', 'July9,2003 ( 2003-07-09 ) (United States)']
# ['August4,2003 ( 2003-08-04 ) ( Los Angeles )', 'August6,2003 ( 2003-08-06 ) (United States)']
# ['August26,2003 ( 2003-08-26 )']
# ['October21,2003 ( 2003-10-21 ) [1]']
# ['November1,2003 ( 2003-11-01 )']
# ['November26,2003 ( 2003-11-26 )']
# ['December25,2003 ( 2003-12-25 )']
# ['January16,2004 ( 2004-01-16 )']
# ['February20,2004 ( 2004-02-20 )']
# ['February10,2004 ( 2004-02-10 )']
# ['February17,2004 ( 2004-02-17 ) (United States)']
# ['March9,2004 ( 2004-03-09 )']
# ['April2,2004 ( 2004-04-02 )']
# ['April22,2004 ( 2004-04-22 )']
# ['June16,2004 ( 2004-06-16 )']
# ['July2,2004 ( 2004-07-02 )']
# ['August11,2004 ( 2004-08-11 )']
# ['August20,2004 ( 2004-08-20 )']
# ['October24,2004 ( 2004-10-24 ) ( El Capitan Theatre )', 'October27,2004 ( 2004-10-27 ) ( BFI London Film Festival )', 'November5,2004 ( 2004-11-05 ) (United States)']
# ['November9,2004 ( 2004-11-09 )']
# ['November19,2004 ( 2004-11-19 )']
# ['January28,2005 ( 2005-01-28 )']
# ['November3,2004 ( 2004-11-03 ) (Italy)', 'February1,2005 ( 2005-02-01 ) (United States)']
# ['February11,2005 ( 2005-02-11 ) [2]']
# ['March4,2005 ( 2005-03-04 )']
# ['March18,2005 ( 2005-03-18 )']
# ['June18,2005 ( 2005-06-18 )']
# ['June22,2005 ( 2005-06-22 )']
# None
# ['July29,2005 ( 2005-07-29 ) [1]']
# ['March25,2005 ( 2005-03-25 ) (UK)', 'August19,2005 ( 2005-08-19 ) (US)']
# ['August30,2005 ( 2005-08-30 )']
# ['September13,2005 ( 2005-09-13 )']
# ['September30,2005 ( 2005-09-30 )']
# ['October30,2005 ( 2005-10-30 ) ( El Capitan Theatre )', 'November4,2005 ( 2005-11-04 ) (United States)']
# ['December7,2005 ( 2005-12-07 ) ( Royal Film Performance )', 'December8,2005 ( 2005-12-08 ) (United Kingdom)', 'December9,2005 ( 2005-12-09 ) (United States)']
# December13,2005 ( 2005-12-13 )
# January13,2006 ( 2006-01-13 )
# ['January26,2006 ( 2006-01-26 ) (Argentina)', 'February7,2006 ( 2006-02-07 ) (United States)']
# ['January27,2006 ( 2006-01-27 )']
# ['February17,2006 ( 2006-02-17 ) (United States)']
# ['March10,2006 ( 2006-03-10 )']
# ['April14,2006 ( 2006-04-14 )']
# ["May26,2006 ( 2006-05-26 ) ( Lowe's Motor Speedway )", 'June9,2006 ( 2006-06-09 ) (United States)']
# ['June23,2006 ( 2006-06-23 )', 'June27,2006 ( 2006-06-27 )']
# ['June24,2006 ( 2006-06-24 ) ( Disneyland Resort )', 'July7,2006 ( 2006-07-07 ) (United States)']
# ['August25,2006 ( 2006-08-25 )']
# ['August29,2006 ( 2006-08-29 )']
# None
# ['November3,2006 ( 2006-11-03 )']
# ['December12,2006 ( 2006-12-12 )']
# ['February6,2007 ( 2007-02-06 )']
# ['February16,2007 ( 2007-02-16 )']
# ['March23,2007 ( 2007-03-23 ) (US)', 'March30,2007 ( 2007-03-30 ) (UK)']
# ['May19,2007 ( 2007-05-19 ) ( Disneyland Resort )', 'May25,2007 ( 2007-05-25 ) (United States)']
# ['June22,2007 ( 2007-06-22 ) ( Kodak Theatre )', 'June29,2007 ( 2007-06-29 ) (United States)']
# None
# ['August3,2007 ( 2007-08-03 )']
# ['August28,2007 ( 2007-08-28 )']
# ['September23,2007 ( 2007-09-23 ) ( Hollywood )', 'September28,2007 ( 2007-09-28 ) (United States)']
# ['October20,2007 ( 2007-10-20 ) ( London )', 'November21,2007 ( 2007-11-21 ) (United States)']
# ['December21,2007 ( 2007-12-21 )']
# February 1, 2008
# ['March7,2008 ( 2008-03-07 )']
# ['May7,2008 ( 2008-05-07 ) ( New York City )', 'May16,2008 ( 2008-05-16 ) (United States)', 'June26,2008 ( 2008-06-26 ) (United Kingdom)']
# ['June23,2008 ( 2008-06-23 ) ( Los Angeles )', 'June27,2008 ( 2008-06-27 ) (United States)']
# ['August26,2008 ( 2008-08-26 )']
# ['October28,2008 ( 2008-10-28 )']
# ['October3,2008 ( 2008-10-03 ) (United States)']
# October17,2008 ( 2008-10-17 )
# ['October17,2008 ( 2008-10-17 ) (London)', 'October24,2008 ( 2008-10-24 ) (United States)']
# ['23October2008 ( 2008-10-23 ) (Kuwait) [1]', '24October2008 ( 2008-10-24 ) (India and United States)']
# ['November21,2008 ( 2008-11-21 )']
# ['December25,2008 ( 2008-12-25 )']
# ['February27,2009 ( 2009-02-27 )']
# ['March11,2009 ( 2009-03-11 ) (Egypt)', 'March13,2009 ( 2009-03-13 ) (United States)']
# ['April10,2009 ( 2009-04-10 )']
# ['10October2007 ( 2007-10-10 ) (France)', '16November2007 ( 2007-11-16 ) (United Kingdom)', '12January2008 ( 2008-01-12 ) (Germany)', '22April2009 ( 2009-04-22 ) (United States)']
# ['April24,2009 ( 2009-04-24 ) (San Francisco International Film Festival)', 'May22,2009 ( 2009-05-22 ) (United States)']
# ['May13,2009 ( 2009-05-13 ) ( Cannes )', 'May29,2009 ( 2009-05-29 ) (United States)']
# None
# ['July24,2009 ( 2009-07-24 )']
# None
# ['June5,2009 ( 2009-06-05 ) (Japan)', 'October27,2009 ( 2009-10-27 ) (United States)', 'February15,2010 ( 2010-02-15 ) (Hindi)']
# ['2008 ( 2008 )']
# ['October 29, 2009 ( October 29, 2009 )']
# ['November3,2009 ( 2009-11-03 ) ( London )', 'November6,2009 ( 2009-11-06 ) (United States)']
# ['November25,2009 ( 2009-11-25 )']
# ['November25,2009 ( 2009-11-25 ) (Los Angeles premiere)', 'December11,2009 ( 2009-12-11 ) (United States)']
# ['February25,2010 ( 2010-02-25 ) ( Odeon Leicester Square )', 'March5,2010 ( 2010-03-05 ) (United States)']
# ['October17,2009 ( 2009-10-17 ) ( Tokyo International Film Festival )', 'January24,2010 ( 2010-01-24 ) (France)']
# ['May9,2010 ( 2010-05-09 ) (London premiere)', 'May28,2010 ( 2010-05-28 ) (United States)']
# ['June12,2010 ( 2010-06-12 ) ( Taormina Film Fest )', 'June18,2010 ( 2010-06-18 ) (United States)']
# ['July8,2010 ( 2010-07-08 ) (Fantasia Film Festival)', 'July14,2010 ( 2010-07-14 )']
# None
# ['August13,2010 ( 2010-08-13 ) (United Kingdom)', 'September21,2010 ( 2010-09-21 ) (United States)']
# ['26October2008 ( 2008-10-26 ) ( France )', '29September2009 ( 2009-09-29 ) ( United Kingdom )']
# ['September30,2010 ( 2010-09-30 ) ( Hollywood )', 'October8,2010 ( 2010-10-08 ) (United States)']
# ['8October2010 ( 2010-10-08 )']
# ['November14,2010 ( 2010-11-14 ) ( El Capitan Theatre )', 'November24,2010 ( 2010-11-24 ) (United States)']
# ['November30,2010 ( 2010-11-30 ) (Tokyo)', 'December17,2010 ( 2010-12-17 ) (United States) [1]']
# None
# ['February1,2011 ( 2011-02-01 )']
# ['17February2011 ( 2011-02-17 )']
# ['March6,2011 ( 2011-03-06 ) ( El Capitan Theatre )', 'March11,2011 ( 2011-03-11 ) (United States)']
# ['22April2011 ( 2011-04-22 )']
# ['April22,2011 ( 2011-04-22 ) (United States)', 'February1,2012 ( 2012-02-01 ) (France)', 'April27,2012 ( 2012-04-27 ) (United Kingdom)']
# ['April29,2011 ( 2011-04-29 )']
# ['May7,2011 ( 2011-05-07 ) ( Disneyland Resort )', 'May20,2011 ( 2011-05-20 ) (United States)']
# ['June18,2011 ( 2011-06-18 ) (Hollywood)', 'June24,2011 ( 2011-06-24 ) (United States)']
# ['April6,2011 ( 2011-04-06 ) (Belgium)', 'July15,2011 ( 2011-07-15 ) (United States)']
# ['September20,2011 ( 2011-09-20 )']
# ['November4,2011 ( 2011-11-04 ) (Savannah Film Festival)', 'November23,2011 ( 2011-11-23 ) (United States)']
# ['January31,2012 ( 2012-01-31 )']
# None
# ['February22,2012 ( 2012-02-22 ) ( LosAngeles )', 'March9,2012 ( 2012-03-09 ) (UnitedStates)']
# ['April20,2012 ( 2012-04-20 ) (United States)', 'February20,2013 ( 2013-02-20 ) (France)', 'May3,2013 ( 2013-05-03 ) (United Kingdom)']
# ['25May2012 ( 2012-05-25 )']
# ['June10,2012 ( 2012-06-10 ) ( SIFF )', 'June22,2012 ( 2012-06-22 ) (United States)']
# ['August15,2012 ( 2012-08-15 )']
# ['August16,2012 ( 2012-08-16 ) (Ukraine)', 'August31,2012 ( 2012-08-31 ) (United States (limited))', 'October23,2012 ( 2012-10-23 ) (DVD release)']
# ['September18,2012 ( 2012-09-18 )']
# ['September20,2012 ( 2012-09-20 ) (Fantastic Fest)', 'October5,2012 ( 2012-10-05 ) (United States)']
# ['October29,2012 ( 2012-10-29 ) ( El Capitan Theatre [2] )', 'November2,2012 ( 2012-11-02 ) (United States)']
# ['February14,2013 ( 2013-02-14 ) ( El Capitan Theatre )', 'March8,2013 ( 2013-03-08 ) (United States)']
# ['16March2011 ( 2011-03-16 ) (France)', '16April2013 ( 2013-04-16 ) (United States)']
# ['June5,2013 ( 2013-06-05 ) ( BFI Southbank )', 'June21,2013 ( 2013-06-21 ) (United States)']
# ['June22,2013 ( 2013-06-22 ) ( Hyperion Theatre )', 'July3,2013 ( 2013-07-03 ) (United States)']
# ['August2,2013 ( 2013-08-02 ) ( EAA AirVenture Oshkosh ) [5]', 'August9,2013 ( 2013-08-09 ) (United States) [6]']
# ['August27,2013 ( 2013-08-27 )']
# ['November19,2013 ( 2013-11-19 ) ( El Capitan Theatre )', 'November22,2013 ( 2013-11-22 ) (United States) [1]']
# ['October20,2013 ( 2013-10-20 ) ( BFI London Film Festival )', 'November29,2013 ( 2013-11-29 ) (United Kingdom)', 'December13,2013 ( 2013-12-13 ) (United States)', 'January9,2014 ( 2014-01-09 ) (Australia)']
# ['February13,2014 ( 2014-02-13 ) (Denmark) [2]', 'April1,2014 ( 2014-04-01 ) (United States) [3]']
# ['March11,2014 ( 2014-03-11 ) ( El Capitan Theatre )', 'March21,2014 ( 2014-03-21 ) (United States)']
# ['April18,2014 ( 2014-04-18 ) (United States)']
# ['May6,2014 ( 2014-05-06 ) ( El Capitan Theatre )', 'May16,2014 ( 2014-05-16 ) (United States)']
# ['May28,2014 ( 2014-05-28 ) ( El Capitan Theatre )', 'May30,2014 ( 2014-05-30 ) (United States)']
# ['July15,2014 ( 2014-07-15 ) ( El Capitan Theatre )', 'July18,2014 ( 2014-07-18 ) (United States)']
# ['19September2014 ( 2014-09-19 )']
# ['October6,2014 ( 2014-10-06 ) ( El Capitan Theatre )', 'October10,2014 ( 2014-10-10 ) (United States)']
# ['October23,2014 ( 2014-10-23 ) ( Tokyo International Film Festival )', 'October31,2014 ( 2014-10-31 ) ( Abu Dhabi Film Festival )', 'November7,2014 ( 2014-11-07 ) (United States)']
# ['December8,2014 ( 2014-12-08 ) ( Ziegfeld Theatre )', 'December25,2014 ( 2014-12-25 ) (United States)']
# ['February9,2015 ( 2015-02-09 ) ( Hollywood )', 'February20,2015 ( 2015-02-20 ) (United States)']
# ['December12,2014 ( 2014-12-12 ) (United Kingdom)', 'March3,2015 ( 2015-03-03 ) (United States)']
# ['February13,2015 ( 2015-02-13 ) ( Berlin )', 'March13,2015 ( 2015-03-13 ) (United States)', 'March27,2015 ( 2015-03-27 ) (United Kingdom)']
# ['April17,2015 ( 2015-04-17 ) (United States)']
# ['May9,2015 ( 2015-05-09 ) ( Disneyland )', 'May22,2015 ( 2015-05-22 ) (United States)']
# ['May18,2015 ( 2015-05-18 ) ( Cannes )', 'June19,2015 ( 2015-06-19 ) (United States)']
# ['19June2015 ( 2015-06-19 )']
# ['November10,2015 ( 2015-11-10 ) ( Paris )', 'November25,2015 ( 2015-11-25 ) (United States)']
# ['January25,2016 ( 2016-01-25 ) ( TCL Chinese Theatre )', 'January29,2016 ( 2016-01-29 ) (United States)']
# ['February13,2016 ( 2016-02-13 ) (Belgium)', 'March4,2016 ( 2016-03-04 ) (United States)']
# ['April4,2016 ( 2016-04-04 ) ( El Capitan Theatre )', 'April15,2016 ( 2016-04-15 ) (United States)']
# None
# ['May10,2016 ( 2016-05-10 ) ( London )', 'May27,2016 ( 2016-05-27 ) (United States)']
# ['June8,2016 ( 2016-06-08 ) ( El Capitan Theatre )', 'June17,2016 ( 2016-06-17 ) (United States)']
# ['May14,2016 ( 2016-05-14 ) ( Cannes )', 'July1,2016 ( 2016-07-01 ) (United States)', 'July22,2016 ( 2016-07-22 ) (United Kingdom)']
# ['August8,2016 ( 2016-08-08 ) ( El Capitan Theatre )', 'August12,2016 ( 2016-08-12 ) (United States)']
# ['September10,2016 ( 2016-09-10 ) ( TIFF )', 'September23,2016 ( 2016-09-23 ) (United States)']
# ['November14,2016 ( 2016-11-14 ) ( AFI Fest )', 'November23,2016 ( 2016-11-23 ) (United States)']
# ['21December2016 ( 2016-12-21 ) (United States)', '23December2016 ( 2016-12-23 ) (India)']
# ['26January2005 ( 2005-01-26 )']
# ['February23,2017 ( 2017-02-23 ) ( Spencer House )', 'March17,2017 ( 2017-03-17 ) (United States)']
# None
# ['May11,2017 ( 2017-05-11 ) ( Shanghai Disney Resort )', 'May26,2017 ( 2017-05-26 ) (United States)']
# ['May23,2017 ( 2017-05-23 ) ( Kannapolis )', 'June16,2017 ( 2017-06-16 ) (United States)']
# ['June30,2017 ( 2017-06-30 ) (United States)']
# ['14July2017 ( 2017-07-14 )']
# ['October29,2017 ( 2017-10-29 ) ( Russia )']
# ['October20,2017 ( 2017-10-20 ) ( Morelia ) [4]', 'November22,2017 ( 2017-11-22 ) (United States)']
# ['February26,2018 ( 2018-02-26 ) ( El Capitan Theatre )', 'March9,2018 ( 2018-03-09 ) (United States)']
# ['June5,2018 ( 2018-06-05 ) ( Los Angeles )', 'June15,2018 ( 2018-06-15 ) (United States)']
# ['July30,2018 ( 2018-07-30 ) ( Burbank )', 'August3,2018 ( 2018-08-03 ) (United States)']
# ['October29,2018 ( 2018-10-29 ) ( Dolby Theatre )', 'November2,2018 ( 2018-11-02 ) (United States)']
# ['November5,2018 ( 2018-11-05 ) ( El Capitan Theatre )', 'November21,2018 ( 2018-11-21 ) (United States)']
# ['November29,2018 ( 2018-11-29 ) ( Dolby Theatre )', 'December19,2018 ( 2018-12-19 ) (United States)']
# ['March11,2019 ( 2019-03-11 ) ( Los Angeles )', 'March29,2019 ( 2019-03-29 ) (United States)']
# ['April17,2019 ( 2019-04-17 ) (United States)']
# ['May8,2019 ( 2019-05-08 ) ( Grand Rex )', 'May24,2019 ( 2019-05-24 ) (United States)']
# ['June11,2019 ( 2019-06-11 ) ( El Capitan Theatre )', 'June21,2019 ( 2019-06-21 ) (United States)']
# ['July9,2019 ( 2019-07-09 ) ( Hollywood )', 'July19,2019 ( 2019-07-19 ) (United States)']
# ['October18,2019 ( 2019-10-18 ) [2]']
# ['November12,2019 ( 2019-11-12 ) (United States)']
# ['November12,2019 ( 2019-11-12 ) (United States)']
# ['November7,2019 ( 2019-11-07 ) ( Dolby Theatre )', 'November22,2019 ( 2019-11-22 ) (United States)']
# ['December20,2019 ( 2019-12-20 ) (United States)']
# ['January25,2020 ( 2020-01-25 ) ( Sundance )', 'February7,2020 ( 2020-02-07 ) ( Disney+ )']
# ['February21,2020 ( 2020-02-21 ) ( Berlinale )', 'March6,2020 ( 2020-03-06 ) (United States)']
# ['March13,2020 ( 2020-03-13 ) (United States) [1]']
# ['March28,2018 ( 2018-03-28 ) (France)', 'April3,2020 ( 2020-04-03 ) ( Disney+ ) [1]']
# ['April3,2020 ( 2020-04-03 )']
# ['June12,2020 ( 2020-06-12 )']
# ['July3,2020 ( 2020-07-03 )']
# ['July31,2020 ( 2020-07-31 )']
# ['August14,2020 ( 2020-08-14 )']
# ['August21,2020 ( 2020-08-21 ) (United States)']
# ['March9,2020 ( 2020-03-09 ) ( Hollywood )', 'September4,2020 ( 2020-09-04 ) (United States)']
# ['December4,2020 ( 2020-12-04 )']
# ['December11,2020 ( 2020-12-11 ) (United States)']
# ['October11,2020 ( 2020-10-11 ) ( BFI Fest )', 'December25,2020 ( 2020-12-25 ) (United States)']
# ['January1,2021 ( 2021-01-01 ) ( Russia )']
# ['February19,2021 ( 2021-02-19 )']
# ['March5,2021 ( 2021-03-05 ) (United States)']
# ['May18,2021 ( 2021-05-18 ) ( El Capitan Theatre )', 'May28,2021 ( 2021-05-28 ) (United States)']
# ['June13,2021 ( 2021-06-13 ) ( Aquarium of Genoa )', 'June18,2021 ( 2021-06-18 ) (United States)']
# ['July24,2021 ( 2021-07-24 ) ( Disneyland Resort )', 'July30,2021 ( 2021-07-30 ) (United States)']
# ['November24,2021 ( 2021-11-24 )']
# ['March11,2022 ( 2022-03-11 ) (United States)']
# None
# ['2022 ( 2022 )']
# ['November25,1987 ( 1987-11-25 )']
# ['2022 ( 2022 )']
# ['July16,1993 ( 1993-07-16 )']
# May 26, 2023 [1]
# None
# None
# None
# None
# None
# None
# ['June21,2002 ( 2002-06-21 )']
# None
# ['December21,1937 ( 1937-12-21 ) ( Carthay Circle Theatre )']
# ['November26,2003 ( 2003-11-26 )']
# ['June21,1991 ( 1991-06-21 )']
# None
# None
# None
# ['October6,2014 ( 2014-10-06 ) ( El Capitan Theatre )', 'October10,2014 ( 2014-10-10 ) (United States)']
# ['August9,1942 ( 1942-08-09 ) (World Premiere – London)', 'August13,1942 ( 1942-08-13 ) (Premiere – New York City)', 'August21,1942 ( 1942-08-21 ) (U.S.) [1]']
# ['August1,1986 ( 1986-08-01 )']
# ['June21,1996 ( 1996-06-21 )']
# ['June13,1997 ( 1997-06-13 ) (limited release)', 'June27,1997 ( 1997-06-27 ) (wide release)']
# ['July23,1999 ( 1999-07-23 )']
# None
# ['November8,1973 ( 1973-11-08 )']
# None

# %% [markdown]
# ## **TASK 3**
# *Clean-up Process*
#
# *   Clean-up references like [1]
# *   Convert running time to Integer
# *   Convert Dates into DateTime Object
# *   Convert Budget & Box Office Amounts to Integers
# *   Split up Long Strings

# %%
# title Default title text
# Grabbing the links to individual movie pages

def removeParenthesis(date):
  try:
    return date.split(" (")[0]
  except:
    pass
  return None

def convertDate(date):
  if isinstance(date, list):
    date = date[0]
  # date = removeParenthesis(date)
  # print(removeParenthesis(date))
  # print(date)
  formats = ["%B %d, %Y", "%B%d,%Y", "%d %B %Y", "%d %B, %Y", "%d%B%Y", "%d%B,%Y"]
  for format in formats:
    try:
      # print(dt.strptime(date, format))
      return dt.strptime(date, format)
    except:
      pass
    return None

def convertToMoney(temp):
  if isinstance(temp, list):
    temp = temp[0]
  temp = temp.replace(",", "")
  # print(temp)
  numeric_const_pattern = "[-+]? [$]? (?: (?: \d* \. \d+ ) | (?: \d+ \.? ) )(?: [Ee] [+-]? \d+ ) ?"
  rx = re.compile(numeric_const_pattern, re.VERBOSE)
  if "crore" in temp:
    # num = re.sub("[^0-9]", "", temp)
    # num = rx.findall(temp)[0]
    # result = int(140095 * float(num))
    return None
  elif "$" in temp:
    if "–" in temp:
      temp = temp.split("–")[0]
      num = rx.findall(temp)[0]
      num = num.replace("$", "")
      if "million" in temp or "million" in temp:
        result = int(1000000 * float(num))
      elif "billion" in temp or "Billion" in temp:
        result = int(1000000000 * float(num))
      elif "thousand" in temp or "thousand" in temp:
        result = int(1000 * float(num))
      else:
        result = int(num)
      try:
        result = int(num)
      except:
        result = float(num)
    else:
      lists = rx.findall(temp)
      # print(len(lists))
      num = rx.findall(temp)[0]

      if len(lists) > 1:
        num0 = lists[0]
        num1 = lists[1]
        # print(f"num0 = {num0}, num1 = {num1}")
        if "$" in num[0]:
          num = num0
        else:
          num = num1
      
      num = num.replace("$", "")
      # print(num)
      if "million" in temp or "million" in temp:
        result = int(1000000 * float(num))
      elif "billion" in temp or "Billion" in temp:
        result = int(1000000000 * float(num))
      elif "thousand" in temp or "thousand" in temp:
        result = int(1000 * float(num))
      else:
        try:
          result = int(num)
        except:
          result = float(num)
      return result
  else:
    return temp

baseLink = "https://en.wikipedia.org/"
movie_infos = []

links = webpage.select("table.wikitable.sortable tbody tr td i a")

for index, link in enumerate(links):
  try:
    actualLink = baseLink + link["href"]

    # Loading the Webpage
    r = requests.get(actualLink)
    moviePage = bs(r.content)
    
    # removing the "[1]" Tag & "extra (date)"               ###
    for tag in moviePage.find_all(["sup", "span"]):         ###
      tag.decompose()                                       ###

    # Grabbing the Side Info Panel and storing them in a dictionary
    movie_info = {}

    panel = moviePage.find("table", attrs={"class": "infobox vevent"})
    # print(panel)
    panel = panel.find("tbody")
    panel = panel.select("tr")
    for index, tr in enumerate(panel):
      if index == 0:
        movie_info["Title"] = tr.get_text(" ", strip=True)
      else:
        header = tr.find("th")
        if header:
          key = tr.find("th").get_text(" ", strip=True)
          if tr.find("li"):
            value = [item.get_text(" ", strip=True).replace("\xa0", "").replace(" minutes", "") for item in tr.find_all("li")]
          elif tr.find("br"):
            value = [text for text in tr.stripped_strings]
          else:
            temp = tr.find("td").get_text(" ", strip=True).replace("\xa0", "").replace(" minutes", "").replace(" Minutes", "").replace(" min", "").replace("minutes", "").replace("Minutes", "").replace("min", "")
            temp = convertToMoney(temp)
            value = temp
          movie_info[key] = value
          # print(movie_info.get("Release data"))  
        
  except:
    pass
  
  movie_infos.append(movie_info)

for movies in movie_infos:
  temp = movies.get("Release date")
  temp = convertDate(temp)
  # movies.get("Release date") = convertDate(movies.get("Release date"))

# %%
from datetime import datetime as dt

def removeParenthesis(date):
  return date.split("(")[0].rstrip()

def convertDate(date):
  if isinstance(date, list):
    date = date[0]
  
  date = removeParenthesis(date)

  formats = ["%B %d, %Y", "%B%d%Y", "%d %B %Y", "%d %B, %Y", "%d%B%Y", "%d%B,%Y"]

  for format in formats:
    try:
      return dt.strptime(date, format)
    except:
      pass
    return None

  return date

date = ['January 28, 1965 ']

print(convertDate(date))
# Out:
# 1965-01-28 00:00:00
